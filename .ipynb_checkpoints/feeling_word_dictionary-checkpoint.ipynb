# %% [markdown]
# # Learning the PyDictionary library: how to use it and what are feels
#
# Simple loop through a list of "feeling words" to precisely define the spectrum of emotions people experience.
#
# Feeling words source: https://www.verywellfamily.com/feelings-words-from-a-to-z-2086647

# %%
# Packages Required
from PyDictionary import PyDictionary
import spacy

# %%
feelWords= u"""
Angry, Annoyed, Afraid, Awkward, Affectionate, Anxious, Alarmed, Awed, Aggravated, Amazed, Astonished, Amused, Apprehensive, Absorbed, Ambivalent, Ashamed, Able, Addled, Admired, Admirable, Affable, Agreeable, Aggressive, Abandoned

Brave, Bothered, Bewildered, Bitter, Bashful, Blue, Baffled, Blissful, Buoyant, Bereaved, Bold

Cheerful, Cooperative, Confident, Calm, Cold, Curious, Content, Considerate, Cautious, Cranky, Crestfallen, Contrite, Chagrined, Carefree, Composed, Capable, Caring, Careful, Contemptuous, Cross, Concerned, Complacent, Charitable, Crushed, Cantankerous, Compulsive
Defiant, Depressed, Discouraged, Delighted, Disgusted, Determined, Disappointed, Detached, Daring, Disillusioned, Devious, Dismayed, Disenchanted, Doleful, Disinterested, Disdainful, Dismissive, Dejected, Disengaged, Distant
Elated, Enthusiastic, Embarrassed, Edgy, Excited, Envious, Exhausted, Eager, Exuberant, Enraged, Euphoric, Extravagant, Ecstatic, Eager, Emboldened

Funny, Frightened, Fearful, Furious, Fair, Foolish, Frustrated, Forgiving, Flustered, Fulfilled, Fatigued

Grouchy, Guilty, Grief-stricken, Generous, Greedy, Grateful, Grumpy, Guarded, Gleeful, Glad, Gloomy, Glum, Gracious, Grateful 
Happy, Humiliated, Hurt, Helpless, Hopeless, Horrified, Hesitant, Humbled, Heartbroken, Hysterical, Hyperactive,
Irritated, Irritable, Interested, Insecure, Impatient, Inspired, Inspiring, Inadequate, Irrational, Ignorant, Indifferent, Irked, Impertinent, Inquisitive, Isolated

Jealous, Joyful, Joyous, Judgmental, Judged, Jaded, Jocular, Jittery
Kind, Keen

Loving, Lonely, Lackluster, Leery, Lethargic, Listless, Lazy

Mad, Meek, Mean, Miserable, Malevolent, Marvelous, Manipulated, Manipulative, Misunderstood, Mischievous, Mopey, Melodramatic, Moody, Melancholy, Mirthful, Moved, Morose, Manic

Nice, Naughty, Nasty, Nervous, Neglected, Neglectful, Needy, Needed, Naive, Nonchalant, Nonplussed, Numb

Overpowered, Overjoyed, Obedient, Obsessive, Obsessed, Offended, Outraged, Overloaded, Overstimulated, Obstinate, Obligated, Optimistic, Open, Openminded

Panicked, Panicky, Peaceful, Placid, Playful, Pensive, Puzzled, Powerful, Powerless, Pleased, Petty, Petulant, Preoccupied, Proud, Prideful, Prickly, Petrified, Pressured, Perturbed, Peeved, Passive

Quirky, Quarrelsome, Qualified, Quivery, Querulous, Quiet

Relieved, Relaxed, Resentful, Rattled, Refreshed, Repulsed, Rational, Reasonable, Reasoned, Rebellious, Reluctant, Reassured, Remorseful, Reserved, Rejuvenated, Restless, Rattled

Sad, Surprised, Silly, Scared, Sorrowful, Serious, Shy, Satisfied, Sensitive, Safe, Stressed, Stubborn, Sarcastic, Spiteful, Scornful, Secure, Serene, Smug, Sociable, Sympathetic, Startled, Satisfied, Sanguine, Skeptical, Sincere

Thankful, Tearful, Teary, Thoughtful, Tolerant, Tolerated, Trusted, Trusting, Trustworthy, Temperamental, Terrified, Timid, Tired, Tiresome, Troubled, Tickled, Torn, Touched, Threatened, Tender, Tranquil


Uneasy, Uncertain, Uncomfortable, Unruffled, Unafraid, Useless, Useful, Unimpressed, Unappreciated, Undecided, Unruly, Uptight, Unnerved, Unhappy, Unsteady, Uplifted, Unsure

Vivacious, Vain, Vibrant, Violent, Valued, Valuable, Vital, Vexed, Volatile, Vulnerable, Victorious, Victimized, Vacant


Worried, Wary, Weak, Weary, Wistful, Wishful, Willful, Willing, Woeful, Weepy, Whiny, Worn, Whimsical, Warm, Witty, Withdrawn, Worthless, Wronged, Wasted, Worldly

Youthful, Yielding, Yearning

Zany, Zealous, Zestful
"""

# %% [markdown]
# ## Cleaning raw word list from Website
#
# Replacing newline characters with commas to get a comma separated list of words then breaking the string up

# %%
feelWordsList = list(map(lambda x: x.strip(), list(set(feelWords.replace("\n", ",").split(",")))))
feelWordsList.remove("")
feelWordsList = list(set(feelWordsList))
feelWordsList.sort()

# %%
len(feelWordsList)
# Out:
# 350

# %%
feelDict = { word.strip():"" for word in feelWords if len(word) > 0}

# %%
# feelDict
# Out:
# {'Angry': '',
#  'Annoyed': '',
#  'Afraid': '',
#  'Awkward': '',
#  'Affectionate': '',
#  'Anxious': '',
#  'Alarmed': '',
#  'Awed': '',
#  'Aggravated': '',
#  'Amazed': '',
#  'Astonished': '',
#  'Amused': '',
#  'Apprehensive': '',
#  'Absorbed': '',
#  'Ambivalent': '',
#  'Ashamed': '',
#  'Able': '',
#  'Addled': '',
#  'Admired': '',
#  'Admirable': '',
#  'Affable': '',
#  'Agreeable': '',
#  'Aggressive': '',
#  'Abandoned': '',
#  'Brave': '',
#  'Bothered': '',
#  'Bewildered': '',
#  'Bitter': '',
#  'Bashful': '',
#  'Blue': '',
#  'Baffled': '',
#  'Blissful': '',
#  'Buoyant': '',
#  'Bereaved': '',
#  'Bold': '',
#  'Cheerful': '',
#  'Cooperative': '',
#  'Confident': '',
#  'Calm': '',
#  'Cold': '',
#  'Curious': '',
#  'Content': '',
#  'Considerate': '',
#  'Cautious': '',
#  'Cranky': '',
#  'Crestfallen': '',
#  'Contrite': '',
#  'Chagrined': '',
#  'Carefree': '',
#  'Composed': '',
#  'Capable': '',
#  'Caring': '',
#  'Careful': '',
#  'Contemptuous': '',
#  'Cross': '',
#  'Concerned': '',
#  'Complacent': '',
#  'Charitable': '',
#  'Crushed': '',
#  'Cantankerous': '',
#  'Compulsive': '',
#  'Defiant': '',
#  'Depressed': '',
#  'Discouraged': '',
#  'Delighted': '',
#  'Disgusted': '',
#  'Determined': '',
#  'Disappointed': '',
#  'Detached': '',
#  'Daring': '',
#  'Disillusioned': '',
#  'Devious': '',
#  'Dismayed': '',
#  'Disenchanted': '',
#  'Doleful': '',
#  'Disinterested': '',
#  'Disdainful': '',
#  'Dismissive': '',
#  'Dejected': '',
#  'Disengaged': '',
#  'Distant': '',
#  'Elated': '',
#  'Enthusiastic': '',
#  'Embarrassed': '',
#  'Edgy': '',
#  'Excited': '',
#  'Envious': '',
#  'Exhausted': '',
#  'Eager': '',
#  'Exuberant': '',
#  'Enraged': '',
#  'Euphoric': '',
#  'Extravagant': '',
#  'Ecstatic': '',
#  'Emboldened': '',
#  'Funny': '',
#  'Frightened': '',
#  'Fearful': '',
#  'Furious': '',
#  'Fair': '',
#  'Foolish': '',
#  'Frustrated': '',
#  'Forgiving': '',
#  'Flustered': '',
#  'Fulfilled': '',
#  'Fatigued': '',
#  'Grouchy': '',
#  'Guilty': '',
#  'Grief-stricken': '',
#  'Generous': '',
#  'Greedy': '',
#  'Grateful': '',
#  'Grumpy': '',
#  'Guarded': '',
#  'Gleeful': '',
#  'Glad': '',
#  'Gloomy': '',
#  'Glum': '',
#  'Gracious': '',
#  'Happy': '',
#  'Humiliated': '',
#  'Hurt': '',
#  'Helpless': '',
#  'Hopeless': '',
#  'Horrified': '',
#  'Hesitant': '',
#  'Humbled': '',
#  'Heartbroken': '',
#  'Hysterical': '',
#  'Hyperactive': '',
#  'Irritated': '',
#  'Irritable': '',
#  'Interested': '',
#  'Insecure': '',
#  'Impatient': '',
#  'Inspired': '',
#  'Inspiring': '',
#  'Inadequate': '',
#  'Irrational': '',
#  'Ignorant': '',
#  'Indifferent': '',
#  'Irked': '',
#  'Impertinent': '',
#  'Inquisitive': '',
#  'Isolated': '',
#  'Jealous': '',
#  'Joyful': '',
#  'Joyous': '',
#  'Judgmental': '',
#  'Judged': '',
#  'Jaded': '',
#  'Jocular': '',
#  'Jittery': '',
#  'Kind': '',
#  'Keen': '',
#  'Loving': '',
#  'Lonely': '',
#  'Lackluster': '',
#  'Leery': '',
#  'Lethargic': '',
#  'Listless': '',
#  'Lazy': '',
#  'Mad': '',
#  'Meek': '',
#  'Mean': '',
#  'Miserable': '',
#  'Malevolent': '',
#  'Marvelous': '',
#  'Manipulated': '',
#  'Manipulative': '',
#  'Misunderstood': '',
#  'Mischievous': '',
#  'Mopey': '',
#  'Melodramatic': '',
#  'Moody': '',
#  'Melancholy': '',
#  'Mirthful': '',
#  'Moved': '',
#  'Morose': '',
#  'Manic': '',
#  'Nice': '',
#  'Naughty': '',
#  'Nasty': '',
#  'Nervous': '',
#  'Neglected': '',
#  'Neglectful': '',
#  'Needy': '',
#  'Needed': '',
#  'Naive': '',
#  'Nonchalant': '',
#  'Nonplussed': '',
#  'Numb': '',
#  'Overpowered': '',
#  'Overjoyed': '',
#  'Obedient': '',
#  'Obsessive': '',
#  'Obsessed': '',
#  'Offended': '',
#  'Outraged': '',
#  'Overloaded': '',
#  'Overstimulated': '',
#  'Obstinate': '',
#  'Obligated': '',
#  'Optimistic': '',
#  'Open': '',
#  'Openminded': '',
#  'Panicked': '',
#  'Panicky': '',
#  'Peaceful': '',
#  'Placid': '',
#  'Playful': '',
#  'Pensive': '',
#  'Puzzled': '',
#  'Powerful': '',
#  'Powerless': '',
#  'Pleased': '',
#  'Petty': '',
#  'Petulant': '',
#  'Preoccupied': '',
#  'Proud': '',
#  'Prideful': '',
#  'Prickly': '',
#  'Petrified': '',
#  'Pressured': '',
#  'Perturbed': '',
#  'Peeved': '',
#  'Passive': '',
#  'Quirky': '',
#  'Quarrelsome': '',
#  'Qualified': '',
#  'Quivery': '',
#  'Querulous': '',
#  'Quiet': '',
#  'Relieved': '',
#  'Relaxed': '',
#  'Resentful': '',
#  'Rattled': '',
#  'Refreshed': '',
#  'Repulsed': '',
#  'Rational': '',
#  'Reasonable': '',
#  'Reasoned': '',
#  'Rebellious': '',
#  'Reluctant': '',
#  'Reassured': '',
#  'Remorseful': '',
#  'Reserved': '',
#  'Rejuvenated': '',
#  'Restless': '',
#  'Sad': '',
#  'Surprised': '',
#  'Silly': '',
#  'Scared': '',
#  'Sorrowful': '',
#  'Serious': '',
#  'Shy': '',
#  'Satisfied': '',
#  'Sensitive': '',
#  'Safe': '',
#  'Stressed': '',
#  'Stubborn': '',
#  'Sarcastic': '',
#  'Spiteful': '',
#  'Scornful': '',
#  'Secure': '',
#  'Serene': '',
#  'Smug': '',
#  'Sociable': '',
#  'Sympathetic': '',
#  'Startled': '',
#  'Sanguine': '',
#  'Skeptical': '',
#  'Sincere': '',
#  'Thankful': '',
#  'Tearful': '',
#  'Teary': '',
#  'Thoughtful': '',
#  'Tolerant': '',
#  'Tolerated': '',
#  'Trusted': '',
#  'Trusting': '',
#  'Trustworthy': '',
#  'Temperamental': '',
#  'Terrified': '',
#  'Timid': '',
#  'Tired': '',
#  'Tiresome': '',
#  'Troubled': '',
#  'Tickled': '',
#  'Torn': '',
#  'Touched': '',
#  'Threatened': '',
#  'Tender': '',
#  'Tranquil': '',
#  'Uneasy': '',
#  'Uncertain': '',
#  'Uncomfortable': '',
#  'Unruffled': '',
#  'Unafraid': '',
#  'Useless': '',
#  'Useful': '',
#  'Unimpressed': '',
#  'Unappreciated': '',
#  'Undecided': '',
#  'Unruly': '',
#  'Uptight': '',
#  'Unnerved': '',
#  'Unhappy': '',
#  'Unsteady': '',
#  'Uplifted': '',
#  'Unsure': '',
#  'Vivacious': '',
#  'Vain': '',
#  'Vibrant': '',
#  'Violent': '',
#  'Valued': '',
#  'Valuable': '',
#  'Vital': '',
#  'Vexed': '',
#  'Volatile': '',
#  'Vulnerable': '',
#  'Victorious': '',
#  'Victimized': '',
#  'Vacant': '',
#  'Worried': '',
#  'Wary': '',
#  'Weak': '',
#  'Weary': '',
#  'Wistful': '',
#  'Wishful': '',
#  'Willful': '',
#  'Willing': '',
#  'Woeful': '',
#  'Weepy': '',
#  'Whiny': '',
#  'Worn': '',
#  'Whimsical': '',
#  'Warm': '',
#  'Witty': '',
#  'Withdrawn': '',
#  'Worthless': '',
#  'Wronged': '',
#  'Wasted': '',
#  'Worldly': '',
#  'Youthful': '',
#  'Yielding': '',
#  'Yearning': '',
#  'Zany': '',
#  'Zealous': '',
#  'Zestful': ''}

# %% [markdown]
# ## New Dict, who dis?
#
# Grabbing the library and starting to generate definitons - in a dictionary!

# %%
dictionary=PyDictionary()

# %%
for feeling in feelDict.keys():
    feelDict[feeling] = dictionary.meaning(feeling)
# Out:
# D:\anaconda3.6\envs\slf_learn\lib\site-packages\PyDictionary\utils.py:5: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 5 of the file D:\anaconda3.6\envs\slf_learn\lib\site-packages\PyDictionary\utils.py. To get rid of this warning, pass the additional argument 'features="html5lib"' to the BeautifulSoup constructor.
#
#   return BeautifulSoup(requests.get(url).text)
# Error: The Following Error occured: list index out of range
# Error: The Following Error occured: list index out of range
# Error: The Following Error occured: list index out of range
# Error: The Following Error occured: list index out of range

# %%
feelDict
# Out:
# {'Angry': {'Adjective': ['feeling or showing anger',
#    '(of the elements',
#    'severely inflamed and painful']},
#  'Annoyed': {'Verb': ['cause annoyance in; disturb, especially by minor irritations'],
#   'Adjective': ['aroused to impatience or anger',
#    'troubled persistently especially with petty annoyances']},
#  'Afraid': {'Adjective': ['filled with fear or apprehension',
#    'filled with regret or concern; used often to soften an unpleasant statement',
#    'feeling worry or concern or insecurity',
#    'having feelings of aversion or unwillingness']},
#  'Awkward': {'Adjective': ['causing inconvenience',
#    'lacking grace or skill in manner or movement or performance',
#    'difficult to handle or manage especially because of shape',
#    'not elegant or graceful in expression',
#    'hard to deal with; especially causing pain or embarrassment',
#    'or embarrassing or difficult',
#    'socially uncomfortable; unsure and constrained in manner']},
#  'Affectionate': {'Adjective': ['having or displaying warmth or affection']},
#  'Anxious': {'Adjective': ['eagerly desirous',
#    'causing or fraught with or showing anxiety']},
#  'Alarmed': {'Verb': ['fill with apprehension or alarm; cause to be unpleasantly surprised',
#    'warn or arouse to a sense of danger or call to a state of preparedness'],
#   'Adjective': ['experiencing a sudden sense of danger']},
#  'Awed': {'Verb': ['inspire awe in'],
#   'Adjective': ['inspired by a feeling of fearful wonderment or reverence',
#    'having or showing a feeling of mixed reverence and respect and wonder and dread']},
#  'Aggravated': {'Verb': ['make worse', 'exasperate or irritate'],
#   'Adjective': ['made more severe or intense especially in law',
#    'incited, especially deliberately, to anger']},
#  'Amazed': {'Verb': ['affect with wonder', 'be a mystery or bewildering to'],
#   'Adjective': ['filled with the emotional impact of overwhelming surprise or shock']},
#  'Astonished': {'Verb': ['affect with wonder'],
#   'Adjective': ['filled with the emotional impact of overwhelming surprise or shock']},
#  'Amused': {'Verb': ['occupy in an agreeable, entertaining or pleasant fashion',
#    'make (somebody'],
#   'Adjective': ['pleasantly occupied']},
#  'Apprehensive': {'Adjective': ['quick to understand',
#    'mentally upset over possible misfortune or danger etc',
#    'in fear or dread of possible evil or harm']},
#  'Absorbed': {'Verb': ['become imbued',
#    'take up mentally',
#    'take up, as of debts or payments',
#    'take in, also metaphorically',
#    'cause to become one with',
#    'suck or take up or in',
#    'devote (oneself',
#    'assimilate or take in',
#    "consume all of one's attention or time"],
#   'Adjective': ['giving or marked by complete attention to',
#    'retained without reflection']},
#  'Ambivalent': {'Adjective': ['uncertain or unable to decide about what course to follow']},
#  'Ashamed': {'Adjective': ['feeling shame or guilt or embarrassment or remorse']},
#  'Able': {'Adjective': ["(usually followed by `to'",
#    'have the skills and qualifications to do things well',
#    'having inherent physical or mental ability or capacity',
#    'having a strong healthy body']},
#  'Addled': {'Verb': ['mix up or confuse', 'become rotten'],
#   'Adjective': ['(of eggs',
#    'confused and vague; used especially of thinking']},
#  'Admired': {'Verb': ['feel admiration for', 'look at with admiration'],
#   'Adjective': ['regarded with admiration']},
#  'Admirable': {'Adjective': ['deserving of the highest esteem or admiration',
#    'inspiring admiration or approval']},
#  'Affable': {'Adjective': ['diffusing warmth and friendliness']},
#  'Agreeable': {'Adjective': ['conforming to your own liking or feelings or nature',
#    'in keeping',
#    'prepared to agree or consent']},
#  'Aggressive': {'Adjective': ['having or showing determination and energetic pursuit of your ends',
#    'tending to spread quickly',
#    'characteristic of an enemy or one eager to fight']},
#  'Abandoned': {'Verb': ['forsake, leave behind',
#    'give up with the intent of never claiming again',
#    'leave behind empty; move out of',
#    'stop maintaining or insisting on; of ideas or claims',
#    'leave someone who needs or counts on you; leave in the lurch'],
#   'Adjective': ['forsaken by owner or inhabitants',
#    'unrestrained and uninhibited']},
#  'Brave': {'Noun': ['a North American Indian warrior', 'people who are brave'],
#   'Verb': ['face and withstand with courage'],
#   'Adjective': ['possessing or displaying courage; able to face and deal with danger or fear without flinching',
#    'invulnerable to fear or intimidation',
#    'brightly colored and showy']},
#  'Bothered': {'Verb': ['take the trouble to do something; concern oneself',
#    'cause annoyance in; disturb, especially by minor irritations',
#    'to cause inconvenience or discomfort to',
#    'intrude or enter uninvited',
#    'make nervous or agitated',
#    'make confused or perplexed or puzzled'],
#   'Adjective': ['caused to show discomposure']},
#  'Bewildered': {'Verb': ['be a mystery or bewildering to',
#    'cause to be confused emotionally'],
#   'Adjective': ['perplexed by many conflicting situations or statements; filled with bewilderment']},
#  'Bitter': {'Noun': ['English term for a dry sharp-tasting ale with strong flavor of hops (usually on draft',
#    'the taste experience when quinine or coffee is taken into the mouth',
#    'the property of having a harsh unpleasant taste'],
#   'Verb': ['make bitter'],
#   'Adjective': ['marked by strong resentment or cynicism',
#    'very difficult to accept or bear',
#    'harsh or corrosive in tone',
#    'expressive of severe grief or regret',
#    'proceeding from or exhibiting great hostility or animosity',
#    'causing a sharp and acrid taste experience',
#    'causing a sharply painful or stinging sensation; used especially of cold'],
#   'Adverb': ['extremely and sharply']},
#  'Bashful': {'Adjective': ['self-consciously timid',
#    'disposed to avoid notice',
#    "`blate' is a Scottish term for bashful"]},
#  'Blue': {'Noun': ['blue color or pigment; resembling the color of the clear sky in the daytime',
#    'blue clothing',
#    'any organization or party whose uniforms or badges are blue',
#    'the sky as viewed during daylight',
#    'used to whiten laundry or hair or give it a bluish tinge',
#    'the sodium salt of amobarbital that is used as a barbiturate; used as a sedative and a hypnotic',
#    'any of numerous small butterflies of the family Lycaenidae'],
#   'Verb': ['turn blue'],
#   'Adjective': ['of the color intermediate between green and violet; having a color similar to that of a clear unclouded sky',
#    'used to signify the Union forces in the American Civil War (who wore blue uniforms',
#    'filled with melancholy and despondency',
#    'characterized by profanity or cursing',
#    'suggestive of sexual impropriety',
#    'belonging to or characteristic of the nobility or aristocracy',
#    'morally rigorous and strict',
#    'causing dejection']},
#  'Baffled': {'Noun': ['people who are frustrated and perplexed'],
#   'Verb': ['be a mystery or bewildering to',
#    'hinder or prevent (the efforts, plans, or desires',
#    'restrain the emission of (sound, fluid, etc.'],
#   'Adjective': ['perplexed by many conflicting situations or statements; filled with bewilderment']},
#  'Blissful': {'Adjective': ['completely happy and contented']},
#  'Buoyant': {'Adjective': ['tending to float on a liquid or rise in air or gas',
#    'characterized by liveliness and lightheartedness']},
#  'Bereaved': {'Noun': ['a person who has suffered the death of someone they loved'],
#   'Verb': ['deprive through death'],
#   'Adjective': ['sorrowful through loss or deprivation']},
#  'Bold': {'Noun': ['a typeface with thick heavy lines'],
#   'Adjective': ['fearless and daring',
#    'clear and distinct',
#    'very steep; having a prominent and almost vertical front']},
#  'Cheerful': {'Adjective': ['being full of or promoting cheer; having or showing good spirits',
#    'pleasantly (even unrealistically']},
#  'Cooperative': {'Noun': ['a jointly owned commercial enterprise (usually organized by farmers or consumers',
#    'an association formed and operated for the benefit of those using it'],
#   'Adjective': ['involving the joint activity of two or more',
#    'done with or working with others for a common purpose or benefit',
#    'willing to adjust to differences in order to obtain agreement']},
#  'Confident': {'Adjective': ['having or marked by confidence or assurance',
#    'persuaded of; very sure',
#    'not liable to error in judgment or action']},
#  'Calm': {'Noun': ['steadiness of mind under stress',
#    'wind moving at less than 1 knot; 0 on the Beaufort scale'],
#   'Verb': ['make calm or still',
#    'make steady',
#    'become quiet or calm, especially after a state of agitation',
#    'cause to be calm or quiet as by administering a sedative to'],
#   'Adjective': ['not agitated; without losing self-possession',
#    '(of weather']},
#  'Cold': {'Noun': ['a mild viral infection involving the nose and respiratory passages (but not the lungs',
#    'the absence of heat',
#    'the sensation produced by low temperatures'],
#   'Adjective': ['having a low or inadequate temperature or feeling a sensation of coldness or having been made cold by e.g. ice or refrigeration',
#    'extended meanings; especially of psychological coldness; without human warmth or emotion',
#    'having lost freshness through passage of time',
#    '(color',
#    'marked by errorless familiarity',
#    'lacking originality or spontaneity; no longer new',
#    'so intense as to be almost uncontrollable',
#    'sexually unresponsive',
#    'without compunction or human feeling',
#    'feeling or showing no enthusiasm',
#    'unconscious from a blow or shock or intoxication',
#    'of a seeker; far from the object sought',
#    'lacking the warmth of life']},
#  'Curious': {'Adjective': ['beyond or deviating from the usual or expected',
#    "eager to investigate and learn or learn more (sometimes about others' concerns"]},
#  'Content': {'Noun': ['(usually plural',
#    'what a communication that is about something is about',
#    'the proportion of a substance that is contained in a mixture or alloy etc.',
#    'the amount that can be contained',
#    'the sum or range of what has been perceived, discovered, or learned',
#    'the state of being contented with your situation in life',
#    'something (a person or object or scene'],
#   'Verb': ['satisfy in a limited way', 'make content'],
#   'Adjective': ['satisfied or showing satisfaction with things as they are']},
#  'Considerate': {'Adjective': ['showing concern for the rights and feelings of others']},
#  'Cautious': {'Noun': ['people who are fearful and cautious'],
#   'Adjective': ['showing careful forethought', 'avoiding excess']},
#  'Cranky': {'Adjective': ['(used of boats', 'easily irritated or annoyed']},
#  'Crestfallen': {'Adjective': ['brought low in spirit']},
#  'Contrite': {'Adjective': ['feeling or expressing pain or sorrow for sins or offenses']},
#  'Chagrined': {'Verb': ['cause to feel shame; hurt the pride of'],
#   'Adjective': ['feeling or caused to feel ill at ease or self-conscious or ashamed']},
#  'Carefree': {'Adjective': ['free of trouble and worry and care',
#    'cheerfully irresponsible']},
#  'Composed': {'Verb': ['form the substance of',
#    'write music',
#    'produce a literary work',
#    'put together out of existing material',
#    'calm (someone, especially oneself',
#    'make up plans or basic details for'],
#   'Adjective': ['serenely self-possessed and free from agitation especially in times of stress']},
#  'Capable': {'Adjective': ["(usually followed by `of'",
#    'possibly accepting or permitting',
#    "(followed by `of'",
#    'having the requisite qualities for',
#    'have the skills and qualifications to do things well']},
#  'Caring': {'Noun': ['a loving feeling'],
#   'Verb': ['feel concern or interest',
#    'provide care for',
#    'prefer or wish to do something',
#    'be in charge of, act on, or dispose of',
#    'be concerned with'],
#   'Adjective': ['feeling and exhibiting concern and empathy for others']},
#  'Careful': {'Adjective': ['exercising caution or showing care or attention',
#    'cautiously attentive',
#    'unhurried and with care and dignity',
#    'full of cares or anxiety',
#    'mindful of the future in spending money']},
#  'Contemptuous': {'Adjective': ['expressing extreme contempt']},
#  'Cross': {'Noun': ['a wooden structure consisting of an upright post with a transverse piece',
#    'a marking that consists of lines that cross each other',
#    'a representation of the structure on which Jesus was crucified; used as an emblem of Christianity or in heraldry',
#    'any affliction that causes great suffering',
#    '(genetics',
#    '(genetics'],
#   'Verb': ['travel across or pass over',
#    'meet at a point',
#    'hinder or prevent (the efforts, plans, or desires',
#    'fold so as to resemble a cross',
#    'to cover or extend over an area or time period',
#    'meet and pass',
#    'trace a line through or across',
#    'breed animals or plants using parents of different races and varieties'],
#   'Adjective': ['extending or lying across; in a crosswise direction; at right angles to the long axis',
#    'annoyed and irritable']},
#  'Concerned': {'Verb': ['be relevant to', 'be on the mind of'],
#   'Adjective': ['feeling or showing worry or solicitude',
#    'involved in or affected by or having a claim to or share in',
#    'culpably involved']},
#  'Complacent': {'Adjective': ["contented to a fault with oneself or one's actions"]},
#  'Charitable': {'Adjective': ['relating to or characterized by charity',
#    'full of love and generosity',
#    'showing or motivated by sympathy and understanding and generosity']},
#  'Crushed': {'Verb': ["come down on or keep down by unjust use of one's authority",
#    'to compress with violence, out of natural shape or condition',
#    'come out better in a competition, race, or conflict',
#    'break into small pieces',
#    'humiliate or depress completely',
#    'crush or bruise',
#    'make ineffective',
#    'become injured, broken, or distorted by pressure'],
#   'Adjective': ['treated so as to have a permanently wrinkled appearance',
#    'subdued or brought low in condition or status']},
#  'Cantankerous': {'Adjective': ['stubbornly obstructive and unwilling to cooperate',
#    'having a difficult and contrary disposition']},
#  'Compulsive': {'Noun': ['a person with a compulsive disposition; someone who feels compelled to do certain things'],
#   'Adjective': ['caused by or suggestive of psychological compulsion',
#    'strongly motivated to succeed']},
#  'Defiant': {'Adjective': ['boldly resisting authority or an opposing force']},
#  'Depressed': {'Verb': ["lower someone's spirits; make downhearted",
#    'lower (prices or markets',
#    'cause to drop or sink',
#    'press down',
#    'lessen the activity or force of'],
#   'Adjective': ['lower than previously',
#    'flattened downward as if pressed from above or flattened along the dorsal and ventral surfaces',
#    'filled with melancholy and despondency']},
#  'Discouraged': {'Verb': ['try to prevent; show opposition to',
#    'deprive of courage or hope; take away hope from; cause to feel discouraged',
#    "advise or counsel in terms of someone's behavior"],
#   'Adjective': ['made less hopeful or enthusiastic', 'lacking in resolution']},
#  'Delighted': {'Verb': ['give pleasure to or be pleasing to',
#    'take delight in',
#    'hold spellbound'],
#   'Adjective': ['greatly pleased', 'filled with wonder and delight']},
#  'Disgusted': {'Verb': ['fill with distaste',
#    'cause aversion in; offend the moral sense of'],
#   'Adjective': ['having a strong distaste from surfeit']},
#  'Determined': {'Verb': ['establish after a calculation, investigation, experiment, survey, or study',
#    'shape or influence; give direction to',
#    'fix conclusively or authoritatively',
#    'decide upon or fix definitely',
#    'reach, make, or come to a decision about something',
#    'fix in scope; fix the boundaries of',
#    'settle conclusively; come to terms',
#    'find out, learn, or determine with certainty, usually by making an inquiry or other effort'],
#   'Adjective': ['characterized by great determination',
#    'having been learned or found or determined especially by investigation',
#    'devoting full strength and concentrated attention to',
#    'determined or decided upon as by an authority',
#    'strongly motivated to succeed']},
#  'Disappointed': {'Verb': ['fail to meet the hopes or expectations of'],
#   'Adjective': ['disappointingly unsuccessful']},
#  'Detached': {'Verb': ['cause to become detached or separated; take off',
#    'separate (a small unit',
#    'come to be detached'],
#   'Adjective': ['showing lack of emotional involvement',
#    'being or feeling set or kept apart from others',
#    'no longer connected or joined',
#    'used of buildings; standing apart from others',
#    'lacking affection or warm feeling',
#    'not fixed in position']},
#  'Daring': {'Noun': ['a challenge to do something dangerous or foolhardy',
#    'the trait of being willing to undertake things that involve risk or danger'],
#   'Verb': ['take upon oneself; act presumptuously, without permission',
#    'to be courageous enough to try or do something',
#    'challenge'],
#   'Adjective': ['disposed to venture or take risks',
#    'radically new or original']},
#  'Disillusioned': {'Verb': ['free from enchantment'],
#   'Adjective': ['freed from illusion']},
#  'Devious': {'Adjective': ['indirect in departing from the accepted or proper way; misleading',
#    'characterized by insincerity or deceit; evasive',
#    'deviating from a straight course']},
#  'Dismayed': {'Verb': ["lower someone's spirits; make downhearted",
#    'fill with apprehension or alarm; cause to be unpleasantly surprised'],
#   'Adjective': ['struck with fear, dread, or consternation']},
#  'Disenchanted': {'Verb': ['free from enchantment'],
#   'Adjective': ['freed from enchantment']},
#  'Doleful': {'Adjective': ['filled with or evoking sadness']},
#  'Disinterested': {'Adjective': ['unaffected by self-interest']},
#  'Disdainful': {'Adjective': ['expressing extreme contempt',
#    'having or showing arrogant superiority to and disdain of those one views as unworthy']},
#  'Dismissive': {'Adjective': ['showing indifference or disregard',
#    'stopping to associate with']},
#  'Dejected': {'Verb': ["lower someone's spirits; make downhearted"],
#   'Adjective': ['affected or marked by low spirits']},
#  'Disengaged': {'Verb': ['release from something that holds fast, connects, or entangles',
#    'free or remove obstruction from',
#    'become free']},
#  'Distant': {'Adjective': ['separated in space or coming from or going to a distance',
#    'far apart in relevance or relationship or kinship',
#    'or remote',
#    'remote in manner',
#    'separate or apart in time',
#    'located far away spatially']},
#  'Elated': {'Verb': ['fill with high spirits; fill with optimism'],
#   'Adjective': ['exultantly proud and joyful; in high spirits',
#    'full of high-spirited delight']},
#  'Enthusiastic': {'Adjective': ['having or showing great excitement and interest']},
#  'Embarrassed': {'Verb': ['cause to be embarrassed; cause to feel self-conscious',
#    'hinder or prevent the progress or accomplishment of'],
#   'Adjective': ['feeling or caused to feel ill at ease or self-conscious or ashamed',
#    'made to feel uncomfortable because of shame or wounded pride']},
#  'Edgy': {'Adjective': ['being in a tense state']},
#  'Excited': {'Verb': ['arouse or elicit a feeling',
#    'act as a stimulant',
#    'stir feelings in',
#    'cause to be agitated, excited, or roused',
#    'stimulate sexually',
#    'stir the feelings, emotions, or peace of',
#    'raise to a higher energy level',
#    'produce a magnetic field in'],
#   'Adjective': ['(of persons',
#    'in an aroused state',
#    'marked by uncontrolled excitement or emotion',
#    '(of e.g. a molecule']},
#  'Envious': {'Adjective': ["showing extreme cupidity; painfully desirous of another's advantages"]},
#  'Exhausted': {'Verb': ['wear out completely',
#    'use up (resources or materials',
#    'deplete',
#    'use up the whole supply of',
#    'eliminate (a substance'],
#   'Adjective': ['drained of energy or effectiveness; extremely tired; completely exhausted',
#    'depleted of energy, force, or strength',
#    'drained physically']},
#  'Eager': {'Noun': ['a high wave (often dangerous',
#    'as by colliding tidal currents or in a narrow estuary'],
#   'Adjective': ['having or showing keen interest or intense desire or impatient expectancy']},
#  'Exuberant': {'Adjective': ['joyously unrestrained',
#    'unrestrained, especially with regard to feelings',
#    'produced or growing in extreme abundance']},
#  'Enraged': {'Verb': ['put into a rage; make violently angry'],
#   'Adjective': ['marked by extreme anger']},
#  'Euphoric': {'Adjective': ['exaggerated feeling of well-being or elation']},
#  'Extravagant': {'Adjective': ['unrestrained, especially with regard to feelings',
#    'recklessly wasteful']},
#  'Ecstatic': {'Adjective': ['feeling great rapture or delight']},
#  'Emboldened': {'Verb': ['give encouragement to'],
#   'Adjective': ['made bold or courageous']},
#  'Funny': {'Noun': ['an account of an amusing incident (usually with a punch line'],
#   'Adjective': ['arousing or provoking laughter',
#    'beyond or deviating from the usual or expected',
#    'not as expected',
#    'experiencing odd bodily sensations']},
#  'Frightened': {'Verb': ['cause fear in'],
#   'Adjective': ['made afraid',
#    'thrown into a state of intense fear or desperation']},
#  'Fearful': {'Adjective': ['experiencing or showing fear',
#    'causing fear or dread or terror',
#    'lacking courage; ignobly timid and faint-hearted',
#    'extremely distressing',
#    'timid by nature or revealing timidity']},
#  'Furious': {'Adjective': ['marked by extreme and violent energy',
#    'marked by extreme anger',
#    '(of the elements']},
#  'Fair': {'Noun': ['a traveling show; having sideshows and rides and games of skill etc.',
#    'gathering of producers to promote business',
#    'a competitive exhibition of farm products',
#    'a sale of miscellany; often for charity'],
#   'Verb': ['join so that the external surfaces blend smoothly'],
#   'Adjective': ['free from favoritism or self-interest or bias or deception; conforming with established standards or rules',
#    'not excessive or extreme',
#    'very pleasing to the eye',
#    '(of a baseball',
#    'lacking exceptional quality or ability',
#    'attractively feminine',
#    '(of a manuscript',
#    'gained or earned without cheating or stealing',
#    'free of clouds or rain',
#    '(used of hair or skin'],
#   'Adverb': ['in conformity with the rules or laws and without fraud or cheating',
#    'without favoring one party, in a fair evenhanded manner']},
#  'Foolish': {'Adjective': ['devoid of good sense or judgment',
#    'having or revealing stupidity']},
#  'Frustrated': {'Verb': ['hinder or prevent (the efforts, plans, or desires',
#    'treat cruelly'],
#   'Adjective': ['disappointingly unsuccessful']},
#  'Forgiving': {'Verb': ['stop blaming or grant forgiveness',
#    'absolve from payment'],
#   'Adjective': ['inclined or able to forgive and show mercy',
#    'providing absolution']},
#  'Flustered': {'Verb': ['be flustered; behave in a confused manner',
#    'cause to be nervous or upset'],
#   'Adjective': ["thrown into a state of agitated confusion; (`rattled' is an informal term"]},
#  'Fulfilled': {'Verb': ['put in effect',
#    'fill, satisfy or meet a want or need or condtion ro restriction',
#    'meet the requirements or expectations of',
#    'put in effect',
#    'meet the requirements or expectations of',
#    'fill, satisfy or meet a want or need or condtion ro restriction'],
#   'Adjective': ['completed to perfection']},
#  'Fatigued': {'Verb': ['lose interest or become bored with something or somebody',
#    'exhaust or get tired through overuse or great strain or stress'],
#   'Adjective': ['drained of energy or effectiveness; extremely tired; completely exhausted']},
#  'Grouchy': {'Adjective': ['annoyed and irritable']},
#  'Guilty': {'Adjective': ['responsible for or chargeable with a reprehensible act',
#    'showing a sense of guilt']},
#  'Grief-stricken': {'Adjective': ['sorrowful through loss or deprivation']},
#  'Generous': {'Adjective': ['willing to give and share unstintingly',
#    'not petty in character and mind',
#    'more than is usual or necessary']},
#  'Greedy': {'Adjective': ['immoderately desirous of acquiring e.g. wealth',
#    'wanting to eat or drink more than one can reasonably consume']},
#  'Grateful': {'Adjective': ['feeling or showing gratitude',
#    'affording comfort or pleasure']},
#  'Grumpy': {'Adjective': ['annoyed and irritable']},
#  'Guarded': {'Verb': ['to keep watch over',
#    'watch over or shield from danger or harm; protect',
#    'protect against a challenge or attack',
#    'take precautions in order to avoid some unwanted consequence'],
#   'Adjective': ['prudent']},
#  'Gleeful': {'Adjective': ['full of high-spirited delight']},
#  'Glad': {'Noun': ['any of numerous plants of the genus Gladiolus native chiefly to tropical and South Africa having sword-shaped leaves and one-sided spikes of brightly colored funnel-shaped flowers; widely cultivated'],
#   'Adjective': ['showing or causing joy and pleasure; especially made happy',
#    'eagerly disposed to act or to be of service',
#    'feeling happy appreciation',
#    'cheerful and bright']},
#  'Gloomy': {'Adjective': ['depressingly dark',
#    'filled with melancholy and despondency',
#    'causing dejection']},
#  'Glum': {'Adjective': ['moody and melancholic',
#    'showing a brooding ill humor']},
#  'Gracious': {'Adjective': ['characterized by charm, good taste, and generosity of spirit',
#    'characterized by kindness and warm courtesy especially of a king to his subjects',
#    'exhibiting courtesy and politeness',
#    'disposed to bestow favors']},
#  'Happy': {'Adjective': ['enjoying or showing or marked by joy or pleasure',
#    'marked by good fortune',
#    'eagerly disposed to act or to be of service',
#    'well expressed and to the point']},
#  'Humiliated': {'Verb': ['cause to feel shame; hurt the pride of'],
#   'Adjective': ['subdued or brought low in condition or status',
#    'made to feel uncomfortable because of shame or wounded pride']},
#  'Hurt': {'Noun': ['any physical damage to the body caused by violence or accident or fracture etc.',
#    'psychological suffering',
#    'feelings of mental or physical pain',
#    'a damage or loss',
#    'the act of damaging something or someone'],
#   'Verb': ['be the source of pain',
#    'give trouble or pain to',
#    'cause emotional anguish or make miserable',
#    'cause damage or affect negatively',
#    'hurt the feelings of',
#    'feel physical pain',
#    'feel pain or be in pain'],
#   'Adjective': ['suffering from physical injury especially that suffered in battle',
#    'damaged; used of inanimate objects or their value']},
#  'Helpless': {'Adjective': ['lacking in or deprived of strength or power',
#    'unable to function; without help',
#    'unable to manage independently']},
#  'Hopeless': {'Adjective': ['without hope because there seems to be no possibility of comfort or success',
#    'of a person unable to do something skillfully',
#    'certain to fail',
#    '(informal to emphasize how bad it is']},
#  'Horrified': {'Verb': ['fill with apprehension or alarm; cause to be unpleasantly surprised'],
#   'Adjective': ['stricken with horror']},
#  'Hesitant': {'Adjective': ['lacking decisiveness of character; unable to act or decide quickly or firmly']},
#  'Humbled': {'Verb': ['cause to be unpretentious',
#    'cause to feel shame; hurt the pride of'],
#   'Adjective': ['subdued or brought low in condition or status']},
#  'Heartbroken': {'Adjective': ['full of sorrow']},
#  'Hysterical': {'Adjective': ['characterized by or arising from psychoneurotic hysteria',
#    'marked by excessive or uncontrollable emotion']},
#  'Hyperactive': {'Adjective': ['more active than normal']},
#  'Irritated': {'Verb': ['cause annoyance in; disturb, especially by minor irritations',
#    'excite to an abnormal condition, or chafe or inflame',
#    'excite to some characteristic action or condition, such as motion, contraction, or nervous impulse, by the application of a stimulus'],
#   'Adjective': ['aroused to impatience or anger']},
#  'Irritable': {'Adjective': ['easily irritated or annoyed',
#    'abnormally sensitive to a stimulus',
#    'capable of responding to stimuli']},
#  'Interested': {'Verb': ['excite the curiosity of; engage the interest of',
#    'be on the mind of',
#    'be of importance or consequence'],
#   'Adjective': ['having or showing interest; especially curiosity or fascination or concern',
#    'involved in or affected by or having a claim to or share in']},
#  'Insecure': {'Adjective': ['not firm or firmly fixed; likely to fail or give way',
#    'lacking in security or safety',
#    'lacking self-confidence or assurance',
#    'not safe from attack']},
#  'Impatient': {'Adjective': ['restless or short-tempered under delay or opposition',
#    "(usually followed by `to'"]},
#  'Inspired': {'Verb': ['heighten or intensify',
#    'supply the inspiration for',
#    'serve as the inciting cause of',
#    'spur on or encourage especially by cheers and shouts',
#    'fill with revolutionary ideas',
#    'draw in (air'],
#   'Adjective': ['being of such surpassing excellence as to suggest inspiration by the gods']},
#  'Inspiring': {'Verb': ['heighten or intensify',
#    'supply the inspiration for',
#    'serve as the inciting cause of',
#    'spur on or encourage especially by cheers and shouts',
#    'fill with revolutionary ideas',
#    'draw in (air'],
#   'Adjective': ['stimulating or exalting to the spirit']},
#  'Inadequate': {'Adjective': ['lacking the requisite qualities or resources to meet a task',
#    'of insufficient quantity to meet a need']},
#  'Irrational': {'Noun': ['a real number that cannot be expressed as a rational number'],
#   'Adjective': ['not consistent with or using reason',
#    'real but not expressible as the quotient of two integers']},
#  'Ignorant': {'Adjective': ['uneducated in general; lacking knowledge or sophistication',
#    'uneducated in the fundamentals of a given art or branch of learning; lacking knowledge of a specific field',
#    'unaware because of a lack of relevant information or knowledge']},
#  'Indifferent': {'Adjective': ['marked by a lack of interest',
#    'showing no care or concern in attitude or action',
#    "(usually followed by `to'",
#    'or indifferent',
#    'fairly poor to not very good',
#    'having only a limited ability to react chemically; chemically inactive',
#    'marked by no especial liking or dislike or preference for one thing over another',
#    'characterized by a lack of partiality',
#    'being neither good nor bad',
#    'neither too great nor too little']},
#  'Irked': {'Verb': ['irritate or vex']},
#  'Impertinent': {'Adjective': ['characterized by a lightly pert and exuberant quality',
#    'not pertinent to the matter under consideration',
#    'improperly forward or bold']},
#  'Inquisitive': {'Adjective': ['showing curiosity',
#    'inquiring or appearing to inquire']},
#  'Isolated': {'Verb': ['place or set apart',
#    'obtain in pure form',
#    'set apart from others',
#    'separate (experiences'],
#   'Adjective': ['not close together in time',
#    'being or feeling set or kept apart from others',
#    'marked by separation of or from usually contiguous elements',
#    'cut off or left behind',
#    'under forced isolation especially for health reasons',
#    'remote and separate physically or socially']},
#  'Jealous': {'Adjective': ["showing extreme cupidity; painfully desirous of another's advantages",
#    'suspicious or unduly suspicious or fearful of being displaced by a rival']},
#  'Joyful': {'Adjective': ['full of or producing joy',
#    'full of high-spirited delight']},
#  'Joyous': {'Adjective': ['full of or characterized by joy']},
#  'Judgmental': {'Adjective': ['depending on judgment']},
#  'Judged': {'Verb': ['determine the result of (a competition',
#    'form a critical opinion of',
#    'judge tentatively or form an estimate of (quantities or time',
#    'pronounce judgment on',
#    'put on trial or hear a case and sit as the judge at the trial of']},
#  'Jaded': {'Verb': ['lose interest or become bored with something or somebody',
#    'exhaust or get tired through overuse or great strain or stress'],
#   'Adjective': ['exhausted', 'dulled by surfeit']},
#  'Jocular': {'Adjective': ['characterized by jokes and good humor'],
#   'Adverb': ['with humor']},
#  'Jittery': {'Adjective': ['characterized by jerky movements',
#    'being in a tense state']},
#  'Kind': {'Noun': ['a category of things distinguished by some common characteristic or quality'],
#   'Adjective': ['having or showing a tender and considerate and helpful nature; used especially of persons and their behavior',
#    'agreeable, conducive to comfort',
#    'tolerant and forgiving under provocation']},
#  'Keen': {'Noun': ['a funeral lament sung with loud wailing'],
#   'Verb': ['express grief verbally'],
#   'Adjective': ['having or demonstrating ability to recognize or draw fine distinctions',
#    'intense or sharp',
#    'very good',
#    'painful as if caused by a sharp instrument',
#    'having a sharp cutting edge or point']},
#  'Loving': {'Verb': ['have a great affection or liking for',
#    'get pleasure from',
#    'be enamored or in love with',
#    'have sexual intercourse with'],
#   'Adjective': ['feeling or showing love and affection']},
#  'Lonely': {'Adjective': ['lacking companions or companionship',
#    'marked by dejection from being alone',
#    'characterized by or preferring solitude',
#    'devoid of creatures']},
#  'Lackluster': {'Adjective': ['lacking brilliance or vitality',
#    'lacking luster or shine']},
#  'Leery': {'Adjective': ['openly distrustful and unwilling to confide']},
#  'Lethargic': {'Adjective': ['deficient in alertness or activity']},
#  'Listless': {'Adjective': ['lacking zest or vivacity',
#    'marked by low spirits; showing no enthusiasm']},
#  'Lazy': {'Adjective': ['moving slowly and gently',
#    'disinclined to work or exertion']},
#  'Mad': {'Adjective': ['roused to anger',
#    'affected with madness or insanity',
#    'marked by uncontrolled excitement or emotion',
#    'very foolish']},
#  'Meek': {'Adjective': ['humble in spirit or manner; suggesting retiring mildness or even cowed submissiveness',
#    'very docile',
#    'evidencing little spirit or courage; overly submissive or compliant']},
#  'Mean': {'Noun': ['an average of n numbers computed by adding some function of the numbers and dividing by some function of n'],
#   'Verb': ['mean or intend to express or convey',
#    'have as a logical consequence',
#    'denote or connote',
#    'have in mind as a purpose',
#    'have a specified degree of importance',
#    'intend to refer to',
#    'destine or designate for a certain purpose'],
#   'Adjective': ['approximating the statistical norm or average or expected value',
#    'characterized by malice',
#    'having or showing an ignoble lack of honor or morality',
#    'excellent',
#    'marked by poverty befitting a beggar',
#    '(used of persons or behavior',
#    '(used of sums of money',
#    'of no value or worth']},
#  'Miserable': {'Adjective': ['very unhappy; full of misery',
#    'deserving or inciting pity',
#    'of the most contemptible kind',
#    'of very poor quality or condition',
#    'characterized by physical misery',
#    'contemptibly small in amount']},
#  'Malevolent': {'Adjective': ['wishing or appearing to wish evil to others; arising from intense ill will or hatred',
#    'having or exerting a malignant influence']},
#  'Marvelous': {'Adjective': ['extraordinarily good or great; used especially as intensifiers',
#    'too improbable to admit of belief',
#    'being or having the character of a miracle']},
#  'Manipulated': {'Verb': ['influence or control shrewdly or deviously',
#    "hold something in one's hands and move it",
#    'tamper, with the purpose of deception',
#    'manipulate in a fraudulent manner',
#    'maintain influence over (others or oneself',
#    'treat manually, as with massage, for therapeutic purposed']},
#  'Manipulative': {'Adjective': ['skillful in influencing or controlling others to your own advantage']},
#  'Misunderstood': {'Verb': ['interpret in the wrong way'],
#   'Adjective': ['wrongly understood']},
#  'Mischievous': {'Adjective': ['naughtily or annoyingly playful',
#    'deliberately causing harm or damage']},
#  'Mopey': None,
#  'Melodramatic': {'Adjective': ['having the excitement and emotional appeal of melodrama',
#    'characteristic of acting or a stage performance; often affected']},
#  'Moody': {'Noun': ["United States tennis player who dominated women's tennis in the 1920s and 1930s (1905-1998",
#    'United States evangelist (1837-1899'],
#   'Adjective': ['showing a brooding ill humor',
#    'subject to sharply varying moods']},
#  'Melancholy': {'Noun': ['a feeling of thoughtful sadness',
#    'a constitutional tendency to be gloomy and depressed',
#    'a humor that was once believed to be secreted by the kidneys or spleen and to cause sadness and melancholy'],
#   'Adjective': ['characterized by or causing or expressing sadness',
#    'grave or even gloomy in character']},
#  'Mirthful': {'Adjective': ['full of or showing high-spirited merriment',
#    'arousing or provoking laughter']},
#  'Moved': {'Verb': ['change location; move, travel, or proceed, also metaphorically',
#    'cause to move or shift into a new position or place, both in a concrete and in an abstract sense',
#    'move so as to change position, perform a nontranslational motion',
#    'change residence, affiliation, or place of employment',
#    'follow a procedure or take a course',
#    'be in a state of action',
#    'go or proceed from one point to another',
#    'perform an action, or work out or perform (an action',
#    'have an emotional or cognitive impact upon',
#    'give an incentive for action',
#    'arouse sympathy or compassion in',
#    'dispose of by selling',
#    'progress by being changed',
#    "live one's life in a specified environment",
#    "have a turn; make one's move in a game",
#    'propose formally; in a debate or parliamentary meeting'],
#   'Adjective': ['being excited or provoked to the expression of an emotion']},
#  'Morose': {'Adjective': ['showing a brooding ill humor']},
#  'Manic': {'Adjective': ['affected with or marked by frenzy or mania uncontrolled by reason']},
#  'Nice': {'Noun': ['a city in southeastern France on the Mediterranean; the leading resort on the French Riviera'],
#   'Adjective': ['pleasant or pleasing or agreeable in nature or appearance',
#    'socially or conventionally correct; refined or virtuous',
#    'done with delicacy and skill',
#    'excessively fastidious and easily disgusted',
#    'exhibiting courtesy and politeness']},
#  'Naughty': {'Adjective': ['suggestive of sexual impropriety',
#    'badly behaved']},
#  'Nasty': {'Adjective': ['offensive or even (of persons',
#    'exasperatingly difficult to handle or circumvent',
#    'characterized by obscenity',
#    'disgustingly dirty; filled or smeared with offensive matter']},
#  'Nervous': {'Adjective': ['easily agitated',
#    'causing or fraught with or showing anxiety',
#    'of or relating to the nervous system',
#    'excited in anticipation',
#    'unpredictably excitable (especially of horses']},
#  'Neglected': {'Verb': ['leave undone or leave out',
#    'fail to do something; leave something undone',
#    'fail to attend to',
#    'give little or no attention to'],
#   'Adjective': ['disregarded', 'lacking a caretaker']},
#  'Neglectful': {'Adjective': ['not showing due care or attention',
#    'failing in what duty requires',
#    'or delinquent']},
#  'Needy': {'Noun': ['needy people collectively'],
#   'Adjective': ['poor enough to need help from others',
#    'demanding or needing attention, affection, or reassurance to an excessive degree']},
#  'Needed': {'Verb': ['require as useful, just, or proper',
#    'have need of',
#    'have or feel a need for'],
#   'Adjective': ['necessary for relief or supply']},
#  'Naive': {'Adjective': ['marked by or showing unaffected simplicity and lack of guile or worldly experience',
#    'of or created by one without formal training; simple or naive in style',
#    'inexperienced',
#    'lacking information or instruction',
#    'not initiated; deficient in relevant experience']},
#  'Nonchalant': {'Adjective': ['marked by blithe unconcern']},
#  'Nonplussed': {'Verb': ['be a mystery or bewildering to'],
#   'Adjective': ['filled with bewilderment']},
#  'Numb': {'Verb': ['make numb or insensitive'],
#   'Adjective': ['lacking sensation',
#    "(followed by `to'",
#    'so frightened as to be unable to move; stunned or paralyzed with terror; petrified']},
#  'Overpowered': {'Verb': ['overcome by superior force',
#    'overcome, as with emotions or perceptual stimuli']},
#  'Overjoyed': {'Verb': ['cause to feel extremely joyful or happy'],
#   'Adjective': ['extremely joyful']},
#  'Obedient': {'Adjective': ['dutifully complying with the commands or instructions of those in authority']},
#  'Obsessive': {'Noun': ['a person who has obsessions'],
#   'Adjective': ['characterized by or constituting an obsession']},
#  'Obsessed': {'Verb': ['haunt like a ghost; pursue',
#    'be preoccupied with something'],
#   'Adjective': ['having or showing excessive or compulsive concern with something',
#    'influenced or controlled by a powerful force such as a strong emotion']},
#  'Offended': {'Verb': ['cause to feel resentment or indignation',
#    'act in disregard of laws, rules, contracts, or promises',
#    'strike with disgust or revulsion',
#    'hurt the feelings of'],
#   'Adjective': ['emotionally hurt or upset or annoyed']},
#  'Outraged': {'Verb': ['strike with disgust or revulsion',
#    'violate the sacred character of a place or language',
#    'force (someone'],
#   'Adjective': ['angered at something unjust or wrong']},
#  'Overloaded': {'Verb': ['become overloaded',
#    'fill to excess so that function is impaired',
#    'place too much a load on'],
#   'Adjective': ['loaded past capacity']},
#  'Overstimulated': None,
#  'Obstinate': {'Verb': ['persist stubbornly'],
#   'Adjective': ['tenaciously unwilling or marked by tenacious unwillingness to yield',
#    'stubbornly persistent in wrongdoing',
#    'resistant to guidance or discipline']},
#  'Obligated': {'Verb': ['force somebody to do something',
#    'commit in order to fulfill an obligation',
#    'bind by an obligation; cause to be indebted'],
#   'Adjective': ['caused by law or conscience to follow a certain course']},
#  'Optimistic': {'Adjective': ['expecting the best in this best of all possible worlds',
#    'expecting the best']},
#  'Open': {'Noun': ['a clear or unobstructed space or expanse of land or water',
#    'where the air is unconfined',
#    'a tournament in which both professionals and amateurs may play',
#    'information that has become public'],
#   'Verb': ['cause to open or to become open',
#    'start to operate or function or cause to start operating or functioning',
#    'become open',
#    'begin or set in action, of meetings, speeches, recitals, etc.',
#    'spread out or open from a closed or folded state',
#    'make available',
#    'become available',
#    'have an opening or passage or outlet',
#    'make the opening move',
#    'afford access to',
#    'display the contents of a file or start an application as on a computer'],
#   'Adjective': ['affording unobstructed entrance and exit; not shut or closed',
#    'affording free passage or access',
#    'with no protection or shield',
#    'open to or in view of all',
#    'used of mouth or eyes',
#    'not having been filled',
#    'accessible to all',
#    'not defended or capable of being defended',
#    '(of textures',
#    'having no protecting cover or enclosure',
#    '(set theory',
#    'not brought to a conclusion; subject to further thought',
#    'not sealed or having been unsealed',
#    'without undue constriction as from e.g. tenseness or inhibition',
#    'ready or willing to receive favorably',
#    'open and observable; not secret or hidden',
#    'not requiring union membership',
#    'possibly accepting or permitting',
#    'affording free passage or view',
#    'openly straightforward and direct without reserve or secretiveness',
#    'ready for business']},
#  'Openminded': None,
#  'Panicked': {'Verb': ['be overcome by a sudden fear',
#    'cause sudden fear in or fill with sudden panic'],
#   'Adjective': ['thrown into a state of intense fear or desperation']},
#  'Panicky': {'Adjective': ['thrown into a state of intense fear or desperation']},
#  'Peaceful': {'Adjective': ['not disturbed by strife or turmoil or war',
#    'peacefully resistant in response to injustice']},
#  'Placid': {'Adjective': ['(of a body of water', 'not easily irritated']},
#  'Playful': {'Adjective': ['full of fun and high spirits']},
#  'Pensive': {'Adjective': ['deeply or seriously thoughtful',
#    'showing pensive sadness']},
#  'Puzzled': {'Verb': ['be a mystery or bewildering to',
#    'be uncertain about; think about without fully understanding or being able to decide'],
#   'Adjective': ['filled with bewilderment']},
#  'Powerful': {'Adjective': ['having great power or force or potency or effect',
#    'strong enough to knock down or overwhelm',
#    'having great influence',
#    '(of a person',
#    'displaying superhuman strength or power'],
#   'Adverb': ['(Southern regional intensive']},
#  'Powerless': {'Adjective': ['lacking power']},
#  'Pleased': {'Verb': ['give pleasure to or be pleasing to',
#    'be the will of or have the will (to',
#    'give satisfaction'],
#   'Adjective': ['experiencing or manifesting pleasure',
#    'feeling pleasurable satisfaction over something by which you measures your self-worth']},
#  'Petty': {'Noun': ['larceny of property having a value less than some amount (the amount varies by locale'],
#   'Adjective': ['inferior in rank or status',
#    '(informal',
#    'or small',
#    'contemptibly narrow in outlook']},
#  'Petulant': {'Adjective': ['easily irritated or annoyed']},
#  'Preoccupied': {'Verb': ['engage or engross the interest or attention of beforehand or occupy urgently or obsessively',
#    'occupy or take possession of beforehand or before another or appropriate for use in advance'],
#   'Adjective': ['deeply absorbed in thought',
#    'having or showing excessive or compulsive concern with something']},
#  'Proud': {'Adjective': ['feeling self-respect or pleasure in something by which you measure your self-worth; or being a reason for pride',
#    'having or displaying great dignity or nobility']},
#  'Prideful': {'Adjective': ['having or showing arrogant superiority to and disdain of those one views as unworthy',
#    'joyful and proud especially because of triumph or success']},
#  'Prickly': {'Adjective': ['very irritable',
#    'having or covered with protective barbs or quills or spines or thorns or setae etc.']},
#  'Petrified': {'Verb': ['cause to become stonelike or stiff or dazed and stunned from fright',
#    'change into stone',
#    'make rigid and set into a conventional pattern']},
#  'Pressured': {'Verb': ['to cause to do through pressure or necessity, by physical, moral or intellectual means',
#    'exert pressure on someone through threats']},
#  'Perturbed': {'Verb': ['disturb in mind or make uneasy or cause to be worried or alarmed',
#    'disturb or interfere with the usual path of an electron or atom',
#    'cause a celestial body to deviate from a theoretically regular orbital motion, especially as a result of interposed or extraordinary gravitational pull',
#    'throw into great confusion or disorder'],
#   'Adjective': ["thrown into a state of agitated confusion; (`rattled' is an informal term"]},
#  'Peeved': {'Verb': ['cause to be annoyed, irritated, or resentful'],
#   'Adjective': ['aroused to impatience or anger']},
#  'Passive': {'Noun': ['the voice used to indicate that the grammatical subject of the verb is the recipient (not the source'],
#   'Adjective': ['lacking in energy or will',
#    'peacefully resistant in response to injustice',
#    'expressing that the subject of the sentence is the patient of the action denoted by the verb']},
#  'Quirky': {'Adjective': ['(informal']},
#  'Quarrelsome': {'Adjective': ['given to quarreling']},
#  'Qualified': {'Verb': ['prove capable or fit; meet requirements',
#    'pronounce fit or able',
#    'make more specific',
#    'make fit or prepared',
#    'specify as a condition or requirement in a contract or agreement; make an express demand or provision in an agreement',
# ...
#    'allow the presence of or allow (an activity']},
#  'Trusted': {'Verb': ['have confidence or faith in',
#    'allow without fear',
#    'be confident about something',
#    'expect and wish',
#    'confer a trust upon',
#    '(chiefly archaic'],
#   'Adjective': ['(of persons', 'or trusted']},
#  'Trusting': {'Verb': ['have confidence or faith in',
#    'allow without fear',
#    'be confident about something',
#    'expect and wish',
#    'confer a trust upon',
#    '(chiefly archaic'],
#   'Adjective': ['inclined to believe or confide readily; full of trust']},
#  'Trustworthy': {'Adjective': ['worthy of trust or belief',
#    "taking responsibility for one's conduct and obligations"]},
#  'Temperamental': {'Adjective': ['relating to or caused by temperament',
#    'subject to sharply varying moods',
#    'likely to perform unpredictably']},
#  'Terrified': {'Verb': ['fill with terror; frighten greatly'],
#   'Adjective': ['thrown into a state of intense fear or desperation']},
#  'Timid': {'Noun': ['people who are fearful and cautious'],
#   'Adjective': ['showing fear and lack of confidence',
#    'lacking self-confidence',
#    'lacking conviction or boldness or courage']},
#  'Tired': {'Verb': ['lose interest or become bored with something or somebody',
#    'exhaust or get tired through overuse or great strain or stress',
#    'deplete',
#    'cause to be bored'],
#   'Adjective': ['depleted of strength or energy',
#    'repeated too often; overfamiliar through overuse']},
#  'Tiresome': {'Adjective': ['so lacking in interest as to cause mental weariness']},
#  'Troubled': {'Verb': ['move deeply',
#    'to cause inconvenience or discomfort to',
#    'disturb in mind or make uneasy or cause to be worried or alarmed',
#    'take the trouble to do something; concern oneself',
#    'cause bodily suffering to and make sick or indisposed'],
#   'Adjective': ['characterized by or indicative of distress or affliction or danger or need',
#    'characterized by unrest or disorder or insubordination']},
#  'Tickled': {'Verb': ['touch (a body part',
#    'feel sudden intense sensation or emotion',
#    'touch or stroke lightly']},
#  'Torn': {'Verb': ['separate or cause to separate abruptly',
#    'to separate or be separated by force',
#    'move quickly and violently',
#    'strip of feathers',
#    'fill with tears or shed tears'],
#   'Adjective': ['having edges that are jagged from injury',
#    'disrupted by the pull of contrary forces']},
#  'Touched': {'Verb': ['make physical contact with, come in contact with',
#    'perceive via the tactile sense',
#    'affect emotionally',
#    'be relevant to',
#    'be in direct physical contact with; make contact',
#    'have an effect upon',
#    'deal with; usually used with a form of negation',
#    'cause to be in brief contact with',
#    'to extend as far as',
#    'be equal to in quality or ability',
#    'tamper with',
#    'make a more or less disguised reference to',
#    'comprehend',
#    'consume',
#    'color lightly'],
#   'Adjective': ['having come into contact',
#    'being excited or provoked to the expression of an emotion',
#    'slightly insane']},
#  'Threatened': {'Verb': ['pose a threat to; present a danger to',
#    'to utter intentions of injury or punishment against',
#    'to be a menacing indication of something'],
#   'Adjective': ['(of flora or fauna']},
#  'Tender': {'Noun': ['something that can be used as an official medium of payment',
#    'someone who waits on or tends to or attends to the needs of another',
#    'a formal proposal to buy at a specified price',
#    'car attached to a locomotive to carry fuel and water',
#    'a boat for communication between ship and shore',
#    'ship that usually provides supplies to other ships'],
#   'Verb': ['offer or present for acceptance',
#    'propose a payment',
#    'make a tender of; in legal settlements',
#    'make tender or more tender as by marinating, pounding, or applying a tenderizer'],
#   'Adjective': ['given to sympathy or gentleness or sentimentality',
#    'hurting',
#    'young and immature',
#    'having or displaying warmth or affection',
#    'easy to cut or chew',
#    'physically untoughened',
#    '(used of boats',
#    '(of plants']},
#  'Tranquil': {'Adjective': ['(of a body of water',
#    'not agitated; without losing self-possession']},
#  'Uneasy': {'Adjective': ['lacking a sense of security or affording no ease or reassurance',
#    'lacking or not affording physical or mental rest',
#    'causing or fraught with or showing anxiety',
#    'socially uncomfortable; unsure and constrained in manner',
#    'relating to bodily unease that causes discomfort']},
#  'Uncertain': {'Adjective': ['lacking or indicating lack of confidence or assurance',
#    'or unsure',
#    'not established beyond doubt; still undecided or unknown',
#    'not established or confirmed',
#    'not certain to occur; not inevitable',
#    'subject to change',
#    'not consistent or dependable',
#    'ambiguous (especially in the negative']},
#  'Uncomfortable': {'Adjective': ['conducive to or feeling mental discomfort',
#    'providing or experiencing physical discomfort']},
#  'Unruffled': {'Adjective': ['free from emotional agitation or nervous tension',
#    '(of a body of water']},
#  'Unafraid': {'Adjective': ['oblivious of dangers or perils or calmly resolute in facing them',
#    'free from fear or doubt; easy in mind']},
#  'Useless': {'Adjective': ['having no beneficial use or incapable of functioning usefully']},
#  'Useful': {'Adjective': ['being of use or service',
#    'having a useful function']},
#  'Unimpressed': {'Adjective': ['not moved to serious regard']},
#  'Unappreciated': {'Adjective': ['not likely to be rewarded',
#    'having value that is not acknowledged']},
#  'Undecided': {'Adjective': ['not brought to a conclusion; subject to further thought',
#    'characterized by indecision',
#    'not yet having made a commitment']},
#  'Unruly': {'Adjective': ['noisy and lacking in restraint or discipline',
#    'unwilling to submit to authority',
#    'incapable of being controlled']},
#  'Uptight': {'Adjective': ['being in a tense state']},
#  'Unnerved': {'Verb': ['disturb the composure of'],
#   'Adjective': ['deprived of courage and strength']},
#  'Unhappy': {'Adjective': ['experiencing or marked by or causing sadness or sorrow or discontent',
#    'or sad',
#    'generalized feeling of distress',
#    'causing discomfort',
#    'marked by or producing unhappiness']},
#  'Unsteady': {'Adjective': ['subject to change or variation',
#    'not firmly or solidly positioned']},
#  'Uplifted': {'Verb': ['fill with high spirits; fill with optimism',
#    'lift up from the earth, as by geologic forces',
#    'lift up or elevate'],
#   'Adjective': ['exalted emotionally especially with pride']},
#  'Unsure': {'Adjective': ['lacking self-confidence',
#    'lacking or indicating lack of confidence or assurance',
#    'or unsure']},
#  'Vivacious': {'Adjective': ['vigorous and animated']},
#  'Vain': {'Adjective': ['characteristic of false pride; having an exaggerated sense of self-importance',
#    'unproductive of success']},
#  'Vibrant': {'Adjective': ['vigorous and animated',
#    'of sounds that are strong and resonating',
#    'of colors that are bright and striking']},
#  'Violent': {'Adjective': ['acting with or marked by or resulting from great force or energy or emotional intensity',
#    'effected by force or injury rather than natural causes',
#    '(of colors or sounds',
#    'marked by extreme intensity of emotions or convictions; inclined to react violently; fervid',
#    'characterized by violence or bloodshed']},
#  'Valued': {'Verb': ['fix or determine the value of; assign a value to',
#    'hold dear',
#    'regard highly; think much of',
#    'evaluate or estimate the nature, quality, ability, extent, or significance of',
#    'estimate the value of'],
#   'Adjective': ['(usually used in combination',
#    'held in great esteem for admirable qualities especially of an intrinsic nature']},
#  'Valuable': {'Noun': ['something of value'],
#   'Adjective': ['having great material or monetary value especially for use or exchange',
#    'having worth or merit or value']},
#  'Vital': {'Adjective': ['urgently needed; absolutely necessary',
#    'performing an essential function in the living body',
#    'full of spirit; full of life',
#    'manifesting or characteristic of life']},
#  'Vexed': {'Verb': ['cause annoyance in; disturb, especially by minor irritations',
#    'disturb the peace of mind of; afflict with mental agitation or distress',
#    'change the arrangement or position of',
#    'subject to prolonged examination, discussion, or deliberation',
#    'be a mystery or bewildering to'],
#   'Adjective': ['troubled persistently especially with petty annoyances',
#    'causing difficulty in finding an answer or solution; much disputed']},
#  'Volatile': {'Noun': ['a volatile substance; a substance that changes readily from solid or liquid to a vapor'],
#   'Adjective': ['evaporating readily at normal temperatures and pressures',
#    'liable to lead to sudden change or violence',
#    'marked by erratic changeableness in affections or attachments',
#    'tending to vary often or widely']},
#  'Vulnerable': {'Adjective': ['susceptible to attack',
#    'susceptible to criticism or persuasion or temptation',
#    'capable of being wounded or hurt']},
#  'Victorious': {'Adjective': ['having won', 'experiencing triumph']},
#  'Victimized': {'Verb': ['make a victim of',
#    'punish unjustly',
#    'deprive of by deceit'],
#   'Adjective': ['(of persons']},
#  'Vacant': {'Adjective': ['void of intelligence or thought',
#    'without an occupant or incumbent']},
#  'Worried': {'Verb': ['be worried, concerned, anxious, troubled, or uneasy',
#    'be concerned with',
#    'disturb the peace of mind of; afflict with mental agitation or distress',
#    'be on the mind of',
#    'lacerate by biting',
#    'touch or rub constantly'],
#   'Adjective': ['afflicted with or marked by anxious uneasiness or trouble or grief',
#    'mentally upset over possible misfortune or danger etc']},
#  'Wary': {'Adjective': ['marked by keen caution and watchful prudence',
#    'openly distrustful and unwilling to confide']},
#  'Weak': {'Adjective': ['wanting in physical strength',
#    'overly diluted; thin and insipid',
#    '(used of vowels or syllables',
#    'wanting in moral strength, courage, or will; having the attributes of man as opposed to e.g. divine beings',
#    'tending downward in price',
#    'deficient or lacking in some skill',
#    'lacking bodily or muscular strength or vitality',
#    '(used of verbs',
#    'or regular',
#    'not having authority, political strength, or governing power',
#    'deficient in magnitude; barely perceptible; lacking clarity or brightness or loudness etc',
#    'likely to fail under stress or pressure',
#    'deficient in intelligence or mental power']},
#  'Weary': {'Verb': ['exhaust or get tired through overuse or great strain or stress',
#    'lose interest or become bored with something or somebody'],
#   'Adjective': ['physically and mentally fatigued']},
#  'Wistful': {'Adjective': ['showing pensive sadness']},
#  'Wishful': {'Adjective': ['having or expressing desire for something',
#    'desiring or striving for recognition or advancement']},
#  'Willful': {'Adjective': ['done by design',
#    'habitually disposed to disobedience and opposition']},
#  'Willing': {'Noun': ['the act of making a choice'],
#   'Verb': ['decree or ordain',
#    'determine by choice',
#    "leave or give by will after one's death"],
#   'Adjective': ['disposed or inclined toward',
#    'not brought about by coercion or force']},
#  'Woeful': {'Adjective': ['affected by or full of grief or woe',
#    'of very poor quality or condition']},
#  'Weepy': {'Adjective': ['liable to weep easily']},
#  'Whiny': {'Adjective': ['habitually complaining']},
#  'Worn': {'Verb': ['be dressed in',
#    "have on one's person",
#    "have in one's aspect; wear an expression of one's attitude or personality",
#    'deteriorate through use or stress',
#    'have or show an appearance of',
#    'last and be usable',
#    'go to pieces',
#    'exhaust or get tired through overuse or great strain or stress',
#    "put clothing on one's body"],
#   'Adjective': ['affected by wear; damaged by long use',
#    'showing the wearing effects of overwork or care or suffering']},
#  'Whimsical': {'Adjective': ['determined by chance or impulse or whim rather than by necessity or reason']},
#  'Warm': {'Verb': ['get warm or warmer', 'make warm or warmer'],
#   'Adjective': ['having or producing a comfortable and agreeable degree of heat or imparting or maintaining heat',
#    'psychologically warm; friendly and responsive',
#    'inducing the impression of warmth; used especially of reds and oranges and yellows when referring to color',
#    'freshly made or left',
#    'easily aroused or excited',
#    'characterized by strong enthusiasm',
#    'characterized by liveliness or excitement or disagreement',
#    'uncomfortable because of possible danger or trouble',
#    'of a seeker; near to the object sought'],
#   'Adverb': ['in a warm manner']},
#  'Witty': {'Adjective': ['combining clever conception and facetious expression']},
#  'Withdrawn': {'Verb': ['pull back or move away or backward',
#    'withdraw from active participation',
#    'release from something that holds fast, connects, or entangles',
#    'cause to be returned',
#    'take back what one has said',
#    'keep away from others',
#    'break from a meeting or gathering',
#    'retire gracefully',
#    'remove (a commodity',
#    'a supply source',
#    'lose interest',
#    'make a retreat from an earlier commitment or activity',
#    'remove something concrete, as by lifting, pushing, or taking off, or remove something abstract'],
#   'Adjective': ['withdrawn from society; seeking solitude',
#    'tending to reserve or introspection']},
#  'Worthless': {'Adjective': ['lacking in usefulness or value',
#    'morally reprehensible']},
#  'Wronged': {'Verb': ['treat unjustly; do wrong to']},
#  'Wasted': {'Verb': ['spend thoughtlessly; throw away',
#    'use inefficiently or inappropriately',
#    'get rid of',
#    'run off as waste',
#    'get rid of (someone who may be a threat',
#    'spend extravagantly',
#    'lose vigor, health, or flesh, as through grief',
#    'cause to grow thin or weak',
#    'cause extensive destruction or ruin utterly',
#    'become physically weaker'],
#   'Adjective': ['serving no useful purpose; having no excuse for being',
#    'not used to good advantage',
#    '(of an organ or body part',
#    'very thin especially from disease or hunger or cold']},
#  'Worldly': {'Adjective': ['characteristic of or devoted to the temporal world as opposed to the spiritual world',
#    'very sophisticated especially because of surfeit; versed in the ways of the world']},
#  'Youthful': {'Adjective': ['suggestive of youth; vigorous and fresh']},
#  'Yielding': {'Noun': ['a verbal act of admitting defeat',
#    'the act of conceding or yielding'],
#   'Verb': ['be the cause or source of',
#    'end resistance, as under pressure or force',
#    'give or supply',
#    'give over; surrender or relinquish to the physical control of another',
#    'give in, as to influence or pressure',
#    'move in order to make room for someone for something',
#    'cause to happen or be responsible for',
#    'be willing to concede',
#    'be fatally overwhelmed',
#    'bring in',
#    'be flexible under stress of physical force',
#    'cease opposition; stop fighting',
#    'consent reluctantly'],
#   'Adjective': ['inclined to yield to argument or influence or control',
#    'lacking stiffness and giving way to pressure',
#    'tending to give in or surrender or agree']},
#  'Yearning': {'Noun': ['prolonged unfulfilled desire or need'],
#   'Verb': ['desire strongly or persistently',
#    'have a desire for something or someone who is not present',
#    'have affection for; feel tenderness for']},
#  'Zany': {'Noun': ['a buffoon in one of the old comedies; imitates others for ludicrous effect',
#    'a man who is a stupid incompetent fool'],
#   'Adjective': ['ludicrous, foolish', 'like a clown']},
#  'Zealous': {'Adjective': ['marked by active interest and enthusiasm']},
#  'Zestful': {'Adjective': ['marked by spirited enjoyment']}}

# %% [markdown]
# # Time for some extra NLP
#
# For funsies, we can take a look at how different these feeling adjectives are from one another in word2vec. Then compare those distances to the distances between a bag of words representation of their definitons, then even a tfidf of their definitions. This could illustrate the value-add of vector representations - and the success of either method would motivate the utility of these advanced NLP techniques.
#
# Subsequently, words could be assembled into an adjacency matrix:
#     words with a sufficiently high similarity score would have edges between them
#     words dissimilar would be part of different components (possibly?!)
#
# Given an adjacency matrix of feels, would we get clusters of emotion words? Would there be components to the graph or would a path exist between any pair of feels? Stay tuned in this data adventure!

# %%
# Load the spacy model that you have installed
import spacy
import en_core_web_md

nlp = en_core_web_md.load()

# %%
spaces= (len(feelDict.keys()) - 1 )*[True]
spaces += [False]

# %%
tokens = nlp(feelWords.replace("\n", " ").replace(","," ").strip())

# %%
#tokens[2].vector
# Out:
# array([ 0.9028503 , -2.0352833 , -3.8119462 , -1.2596028 ,  1.375779  ,
#         1.2130262 ,  8.566614  ,  0.42458633, -1.4295827 ,  1.3153642 ,
#        -1.1270967 , -2.4334588 , -4.1789217 , -4.8340125 , -1.9374647 ,
#         3.8316967 ,  1.8811852 ,  1.4888806 ,  0.3633979 ,  2.8718214 ,
#        -3.6283119 , -2.070569  ,  0.1351679 ,  2.3921592 , -0.68107224,
#         0.08948976,  1.7156159 ,  0.25673836,  0.8787936 ,  3.7089782 ,
#         3.0204272 ,  2.2633293 ,  3.8435059 , -0.5499996 ,  4.264753  ,
#         2.2133975 , -1.6429275 , -1.4032841 ,  1.9742174 , -1.9989924 ,
#         0.5239243 ,  1.4325392 ,  1.5390843 , -1.4421186 ,  1.7566789 ,
#         0.09232055,  0.3786987 ,  3.4560738 ,  3.2127383 ,  0.63673097,
#        -4.990941  ,  4.4185815 , -2.8275707 , -4.5922894 , -0.61132425,
#         2.389515  , -1.5698824 ,  0.5888219 , -4.6780686 , -1.6724204 ,
#        -0.37067753,  0.96263826, -3.407512  , -2.0612578 , -0.9603361 ,
#        -1.6251245 ,  3.1474447 , -2.407372  , -3.8101687 , -0.7185974 ,
#        -1.9964306 ,  1.3874748 ,  0.6705435 , -0.72327155, -3.2127995 ,
#        -2.468423  ,  1.7273247 , -1.2128774 ,  0.07410607,  0.66927195,
#        -2.9674697 , -2.7555726 , -3.7790012 , -0.12466693,  0.15152916,
#         0.14646475,  4.973952  ,  2.4717765 ,  0.82151085, -3.139532  ,
#         3.479066  , -0.2948113 , -5.4197097 ,  5.043785  , -0.66702056,
#         3.6850288 ], dtype=float32)

# %%
feelAdjacencyMtrx = pd.DataFrame(columns=feelWordsList, index=feelWordsList)

# %%
#feelAdjacencyMtrx[feelAdjacencyMtrx.index.duplicated()]

# %%
feelAdjacencyMtrx.head()
# Out:
#           Abandoned Able Absorbed Addled Admirable Admired Affable  \
# Abandoned       NaN  NaN      NaN    NaN       NaN     NaN     NaN
# Able            NaN  NaN      NaN    NaN       NaN     NaN     NaN
# Absorbed        NaN  NaN      NaN    NaN       NaN     NaN     NaN
# Addled          NaN  NaN      NaN    NaN       NaN     NaN     NaN
# Admirable       NaN  NaN      NaN    NaN       NaN     NaN     NaN
#
#           Affectionate Afraid Aggravated   ...   Worn Worried Worthless  \
# Abandoned          NaN    NaN        NaN   ...    NaN     NaN       NaN
# Able               NaN    NaN        NaN   ...    NaN     NaN       NaN
# Absorbed           NaN    NaN        NaN   ...    NaN     NaN       NaN
# Addled             NaN    NaN        NaN   ...    NaN     NaN       NaN
# Admirable          NaN    NaN        NaN   ...    NaN     NaN       NaN
#
#           Wronged Yearning Yielding Youthful Zany Zealous Zestful
# Abandoned     NaN      NaN      NaN      NaN  NaN     NaN     NaN
# Able          NaN      NaN      NaN      NaN  NaN     NaN     NaN
# Absorbed      NaN      NaN      NaN      NaN  NaN     NaN     NaN
# Addled        NaN      NaN      NaN      NaN  NaN     NaN     NaN
# Admirable     NaN      NaN      NaN      NaN  NaN     NaN     NaN
#
# [5 rows x 350 columns]

# %%
import pandas as pd
feelSimilarityDict = {"feelPairs":[], "similarity":[]}
feelPairs = []
similarities = []
# Creating a dictionary where the keys are the pairs of feel words I 
# am comparing and the values are the smiliarity values of the words
for token1 in tokens:
    for token2 in tokens:
        # Ensuring that the words are not spaces, and that word vectors exist for them
        if token1 != token2 and str(token1) != " " and str(token2) != " " \
        and token1.has_vector and token2.has_vector:
            feelPairs.append(str(token1.text)+" "+str(token2.text)) 
            similarities.append(token1.similarity(token2))
            feelAdjacencyMtrx.loc[str(token1).strip(),str(token2).strip()]= token1.similarity(token2)

feelSimilarityDict["feelPairs"] = feelPairs
feelSimilarityDict["similarity"] = similarities
# Creating a dictionary to feed a data frame with the similarity data
feelSimilarityDf = pd.DataFrame(feelSimilarityDict)

# %%
feelAdjacencyMtrx.shape
# Out:
# (353, 353)

# %%
# %matplotlib inline
feelSimilarityDf["similarity"].hist()

# %% [markdown]
# Inspecting how the similarity scores are distributed: turns out most feel words aren't "very" similar. Semantically similar words have scores around 0.8 and up - that corresponds to above the 99.5th percentile of similarity scores

# %%
feelSimilarityDf.describe()
# Out:
#           similarity
# count  124256.000000
# mean        0.301934
# std         0.143317
# min        -0.122915
# 25%         0.202375
# 50%         0.290779
# 75%         0.390593
# max         1.000000

# %%
feelSimilarityDf.quantile(0.995)
# Out:
# similarity    0.748446
# Name: 0.995, dtype: float64

# %%
feelSimilarityDf[feelSimilarityDf["similarity"] >feelSimilarityDf.quantile(0.995)[0]]
# Out:
#                      tokens  similarity
# 0             Angry Annoyed    0.757039
# 142             Angry Irked    0.757039
# 224            Angry Peeved    0.757039
# 348           Annoyed Angry    0.757039
# 358          Annoyed Amused    0.787249
# 372        Annoyed Bothered    0.771098
# 394       Annoyed Chagrined    0.763272
# 412       Annoyed Disgusted    0.763272
# 419        Annoyed Dismayed    0.763272
# 430     Annoyed Embarrassed    0.763687
# 448      Annoyed Frustrated    0.800054
# 450       Annoyed Flustered    0.763687
# 490           Annoyed Irked    1.000000
# 559         Annoyed Puzzled    0.787249
# 572          Annoyed Peeved    1.000000
# 584        Annoyed Repulsed    0.763272
# 647     Annoyed Unimpressed    0.763272
# 946           Afraid Scared    0.855410
# 1018         Afraid Worried    0.806237
# 1836        Anxious Fearful    0.768494
# 1986       Anxious Restless    1.000000
# 2113     Alarmed Bewildered    1.000000
# 2132    Alarmed Crestfallen    0.752671
# 2183     Alarmed Frightened    1.000000
# 2184        Alarmed Fearful    0.833726
# 2213      Alarmed Horrified    0.752671
# 2216    Alarmed Heartbroken    0.752671
# 2293       Alarmed Panicked    0.773689
# 2294        Alarmed Panicky    0.773689
# 2309      Alarmed Petrified    0.924014
# ...                     ...         ...
# 106412    Unnerved Startled    1.000000
# 106426   Unnerved Terrified    0.924014
# 106570     Unhappy Dejected    1.000000
# 106593   Unhappy Frustrated    0.800946
# 106994     Unsteady Jittery    1.000000
# 107548  Unsure Apprehensive    0.780281
# 107663      Unsure Hesitant    0.780281
# 107973  Vivacious Exuberant    1.000000
# 108231    Vivacious Zestful    1.000000
# 110613         Vexed Uneasy    1.000000
# 112410       Worried Afraid    0.806237
# 112433     Worried Bothered    0.752951
# 112463    Worried Concerned    0.771263
# 112657    Worried Surprised    0.753889
# 112659       Worried Scared    0.789987
# 112799        Wary Cautious    0.828739
# 112916           Wary Leery    1.000000
# 115714          Weepy Mopey    1.000000
# 115757       Weepy Petulant    1.000000
# 115770      Weepy Querulous    1.000000
# 115872          Weepy Whiny    1.000000
# 116062          Whiny Mopey    1.000000
# 116105       Whiny Petulant    1.000000
# 116118      Whiny Querulous    1.000000
# 116220          Whiny Weepy    1.000000
# 116811     Whimsical Quirky    1.000000
# 117540      Witty Sarcastic    0.772050
# 118274    Worthless Useless    0.827029
# 121197    Zestful Exuberant    1.000000
# 121418    Zestful Vivacious    1.000000
#
# [606 rows x 2 columns]

# %% [markdown]
# Similarity graph approach 1:
# Creating the adjacency matrix based on similarity score being above or below the .995th percentile based on word vector similarity.

# %%
# feelAdjacencyMtrx = feelAdjacencyMtrx.fillna(0)
# feelAdjacencyMtrx = (feelAdjacencyMtrx > feelSimilarityDf.quantile(0.995)[0])*1

# %%
feelAdjacencyMtrx.loc["Brave","Cold"]
# Out:
# 0.3632873

# %%
import networkx as nx
import numpy as np
from networkx_viewer import Viewer
# G = nx.DiGraph(feelAdjacencyMtrx.values)
# nx.draw(G)
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 8]

labels = {i:feel for i,feel in enumerate(feelWordsList)} 
def show_graph_with_labels(adjacency_matrix, mylabels):
    rows, cols = np.where(adjacency_matrix == 1)
    edges = zip(rows.tolist(), cols.tolist())
    #print(list(edges))
    gr = nx.Graph()
    #pos = nx.circular_layout(gr)

    gr.add_edges_from(edges)
    gr2 = nx.relabel_nodes(gr,mylabels)
    nx.draw_spring(gr2,node_size=110,with_labels=True)
    plt.show()

show_graph_with_labels(feelAdjacencyMtrx.values, labels)

# %%
feelSimilarityDf["UndirectedEdge"] = (feelSimilarityDf["similarity"] > feelSimilarityDf.quantile(0.995)[0]).apply(lambda x: int(x))
